# %% [markdown]
# Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an
# example of each.

# %% [markdown]
# Ans. 1. Simple Linear Regression
# Definition: Simple linear regression uses one independent variable to predict the dependent variable. The relationship between the independent variable
# �
# X and the dependent variable
# �
# Y is modeled by a straight line, represented by the equation:
#
# �
# =
# �
# 0
# +
# �
# 1
# �
# +
# �
# Y=b
# 0
# ​
#  +b
# 1
# ​
#  X+ϵ
# �
# Y: Dependent variable (outcome or response variable)
# �
# X: Independent variable (predictor)
# �
# 0
# b
# 0
# ​
#  : Intercept (the value of
# �
# Y when
# �
# =
# 0
# X=0)
# �
# 1
# b
# 1
# ​
#  : Slope (change in
# �
# Y for a one-unit change in
# �
# X)
# �
# ϵ: Error term (captures the deviation of actual values from the predicted values)

# %% [markdown]
# 2. Multiple Linear Regression
# Definition: Multiple linear regression involves two or more independent variables to predict the dependent variable. The relationship is represented by the equation:
#
# �
# =
# �
# 0
# +
# �
# 1
# �
# 1
# +
# �
# 2
# �
# 2
# +
# …
# +
# �
# �
# �
# �
# +
# �
# Y=b
# 0
# ​
#  +b
# 1
# ​
#  X
# 1
# ​
#  +b
# 2
# ​
#  X
# 2
# ​
#  +…+b
# n
# ​
#  X
# n
# ​
#  +ϵ
# �
# Y: Dependent variable
# �
# 1
# ,
# �
# 2
# ,
# …
# ,
# �
# �
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,…,X
# n
# ​
#  : Independent variables
# �
# 0
# b
# 0
# ​
#  : Intercept
# �
# 1
# ,
# �
# 2
# ,
# …
# ,
# �
# �
# b
# 1
# ​
#  ,b
# 2
# ​
#  ,…,b
# n
# ​
#  : Coefficients for each independent variable
# �
# ϵ: Error term

# %% [markdown]
# Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in
# a given dataset?

# %% [markdown]
# Linear regression relies on a few key assumptions to ensure that its results are valid and reliable.
#
# 1. Linearity,2. Independence,3. Homoscedasticity (Constant Variance of Errors),
# 4. Normality of Residuals,4. Normality of Residuals

# %% [markdown]
# Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using
# a real-world scenario.

# %% [markdown]
# Ans. In a linear regression model, the slope and intercept are key parameters that help describe the relationship between the independent variable(s) and the dependent variable. Here’s what they mean and how to interpret them

# %%
Q4. Explain the concept of gradient descent. How is it used in machine learning?

# %% [markdown]
# Ans Gradient descent is an optimization algorithm used to minimize the error (or loss) of a model by iteratively adjusting its parameters. It’s commonly used in machine learning, especially in training models like linear regression, logistic regression, and neural networks, to find the best parameters that minimize the difference between the model's predictions and actual data
